# %% [markdown]
# <a href="https://colab.research.google.com/github/khatriprajwol/Web-Scrapping-using-Python/blob/main/ECU_WEB_SCRAPPING.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np #a matrix like package for handling data
import pandas as pa #a R like package for handling data
from scipy import stats #a way to just get a piece of a large package
import matplotlib.pyplot as plt #a way to generate plots, histograms, bar charts, and other types of charts 
import seaborn as sns #it is based on matplotlib
import requests #HTTP library
import pandas as pd # used to manipulate data and analyze it
from bs4 import BeautifulSoup #Used for a web scraping purposes to pull the data out of HTML and XML files
import re #Used for regular expression in Python.
import csv

# %%
url= "https://www.ecok.edu/policies-and-handbooks"
page = requests.get(url)
soup = BeautifulSoup(page.content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class=" widescreen" dir="ltr" lang="en" prefix="content: http://purl.org/rss/1.0/modules/content/  dc: http://purl.org/dc/terms/  foaf: http://xmlns.com/foaf/0.1/  og: http://ogp.me/ns#  rdfs: http://www.w3.org/2000/01/rdf-schema#  schema: http://schema.org/  sioc: http://rdfs.org/sioc/ns#  sioct: http://rdfs.org/sioc/types#  skos: http://www.w3.org/2004/02/skos/core#  xsd: http://www.w3.org/2001/XMLSchema# ">
#  <head>
#   <meta charset="utf-8"/>
#   <link href="https://www.ecok.edu/policies-and-handbooks" rel="canonical"/>
#   <meta content="This page serves as the repository for ECU's policies and handbooks for faculty, staff and students." name="description"/>
#   <meta content="This page serves as the repository for ECU's policies and handbooks for faculty, staff and students." name="abstract"/>
#   <meta content="policies, handbook" name="keywords"/>
#   <meta content="East Central University" property="og:site_name"/>
# ...

# %%
print(soup.title)
# Out:
# <title>Policies and Handbooks | East Central University</title>

# %%
print(soup.title.text)
# Out:
# Policies and Handbooks | East Central University

# %%
lists = soup.find('div', class_="region region-content")
table =lists.find('a',class_="btn btn-primary")
table
# Out:
# <a class="btn btn-primary" download="" href="/sites/default/files/website_files/Policies_and_Handbooks/2018-East-Central-University-Adjunct-Faculty-Handbook.pdf" target="_blank">Download</a>

# %%
lists = soup.find('div', class_="region region-content")
table =lists.find('a',class_="btn btn-primary")["href"]
table
# Out:
# '/sites/default/files/website_files/Policies_and_Handbooks/2018-East-Central-University-Adjunct-Faculty-Handbook.pdf'

# %%
name = table.split("/")
name
# Out:
# ['',
#  'sites',
#  'default',
#  'files',
#  'website_files',
#  'Policies_and_Handbooks',
#  '2018-East-Central-University-Adjunct-Faculty-Handbook.pdf']

# %%
name = table.split("/")[6]
name
# Out:
# '2018-East-Central-University-Adjunct-Faculty-Handbook.pdf'

# %%
year = name.split("-")[0]
year
# Out:
# '2018'

# %%
ecu_link = f"https://www.ecok.edu/sites/default/files/website_files/Policies_and_Handbooks/Annual_Safety_Report{year}.pdf"
ecu_link
# Out:
# 'https://www.ecok.edu/sites/default/files/website_files/Policies_and_Handbooks/Annual_Safety_Report2018.pdf'

# %%
url= "https://www.ecok.edu/policies-and-handbooks"
page = requests.get(url)
soup = BeautifulSoup(page.content, 'html.parser')
csv_file = open("ecu_policy_info.csv","w")

csv_writer = csv.writer(csv_file)
csv_writer.writerow(['year', 'info'])

for lists in soup.find_all('div', class_="region region-content"):
  #table =lists.find('a',class_="btn btn-primary")
  #lists = soup.find('div', class_="region region-content")
  
  try:
    table =lists.find('a',class_="btn btn-primary")["href"]
    #name = table.split("/")
    name = table.split("/")[6]
    year = name.split("-")[0]
    ecu_link = f"https://www.ecok.edu/sites/default/files/website_files/Policies_and_Handbooks/Annual_Safety_Report{year}.pdf"
    
  except Exception as e:
    ecu_link = None

  print(ecu_link)
  print()

  csv_writer.writerow([year, ecu_link])

csv_file.close()
# Out:
# https://www.ecok.edu/sites/default/files/website_files/Policies_and_Handbooks/Annual_Safety_Report2018.pdf
